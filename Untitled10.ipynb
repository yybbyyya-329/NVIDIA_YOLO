# %% [markdown]
# <a href="https://colab.research.google.com/github/yybbyyya-329/NVIDIA_YOLO/blob/20250515/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. YOLOv8 설치
# !pip install -q ultralytics

# 2. 라이브러리 임포트
from ultralytics import YOLO
from google.colab import files
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# 3. YOLOv8x 모델 로드
model = YOLO('yolov8x.pt')  # 사전 학습된 COCO 모델

# 4. 이미지 업로드 (Colab에서 실행 시 파일 선택창 뜸)
uploaded = files.upload()

# 5. 업로드한 이미지 파일 경로 얻기
image_path = list(uploaded.keys())[0]

# 6. 이미지 열기
image = Image.open(image_path)

# 7. 객체 감지 수행
results = model(image)

# 8. 'cat' 클래스만 카운트
cat_count = 0
for result in results:
    for box in result.boxes:
        cls_id = int(box.cls[0])
        cls_name = model.names[cls_id]
        if cls_name.lower() == 'cat':
            cat_count += 1

# 9. 결과 출력
print(f"🔍 감지된 고양이 수: {cat_count}")

# 10. 감지된 객체 시각화 (matplotlib 사용)
results[0].show()

# 추가: 결과 이미지 저장하고 보기
results[0].save(filename="detected.jpg")
display(Image.open("detected.jpg"))
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 81.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 854.7 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 81.7 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# ...
