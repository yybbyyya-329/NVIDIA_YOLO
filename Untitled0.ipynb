# %% [markdown]
# <a href="https://colab.research.google.com/github/yybbyyya-329/NVIDIA_YOLO/blob/20250404/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ultarlytics 라이브러리 설치 (YOLOv8을 사용하려면 필요해요)
# !pip install ultralytics -q

#ultralytics에서 제공하는 yolov8x 모델 자동 다운로드
from ultralytics import YOLO

#yolov8x 모델을 불러오면 자동으로 다운로드 돼요
model = YOLO('yolov8x.pt')
print("yolov8x.pt 모델 다운로드 완료!")
# Out:
# yolov8x.pt 모델 다운로드 완료!

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5ced9dac-4edc-4fe6-b715-2bc2e090090e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ced9dac-4edc-4fe6-b715-2bc2e090090e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
results = model.predict(source= '/content/dd.mp4' , save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/218) /content/dd.mp4: 352x640 12 cars, 1 bus, 2 trucks, 62.2ms
# video 1/1 (frame 2/218) /content/dd.mp4: 352x640 12 cars, 1 bus, 2 trucks, 61.9ms
# video 1/1 (frame 3/218) /content/dd.mp4: 352x640 12 cars, 1 bus, 2 trucks, 60.4ms
# video 1/1 (frame 4/218) /content/dd.mp4: 352x640 12 cars, 1 bus, 2 trucks, 55.8ms
# video 1/1 (frame 5/218) /content/dd.mp4: 352x640 12 cars, 1 bus, 2 trucks, 38.5ms
# ...

# %%
# !apt-get install ffmpeg  # ffmpeg 설치 (한 번만 실행)
# !ffmpeg -i /content/runs/detect/predict/dd.avi /content/runs/detect/predict/dd.mp4

from IPython.display import Video

Video("/content/runs/detect/predict/dd.mp4")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
